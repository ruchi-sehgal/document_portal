# %%
from langchain_groq import ChatGroq

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# <function dotenv.main.load_dotenv(dotenv_path: Union[str, ForwardRef('os.PathLike[str]'), NoneType] = None, stream: Optional[IO[str]] = None, verbose: bool = False, override: bool = False, interpolate: bool = True, encoding: Optional[str] = 'utf-8') -> bool>

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model="qwen/qwen3-32b"
)

print(model.invoke("What is the capital of France?").content)
# Out:
# <think>
# Okay, so the user is asking, "What is the capital of France?" Let me think. I know that France is a country in Europe. Capitals are usually the main cities where the government is located. I remember from school that Paris is the capital of France. But wait, I should make sure I'm not mixing it up with another country. Like, is Paris the capital of Germany? No, I think Germany's capital is Berlin. Then there's Italy, which is Rome, and Spain is Madrid. So yeah, Paris for France makes sense.
#
# Let me double-check. Maybe there's a common confusion with cities like Lyon or Marseille. Lyon is a big city in France, known for its cuisine and maybe the headquarters of some companies. Marseille is a port city. But the capital is definitely Paris. I've heard Paris mentioned in news and history related to France's government. Also, the Eiffel Tower is in Paris, which is a famous landmark. That's a good indicator. The Louvre Museum is there too. So all these cultural landmarks point to Paris being the capital. I don't think there's any other city in France that's more prominent in terms of government and politics. Yeah, I'm pretty confident that Paris is the correct answer here. The user probably expects a straightforward answer, so I should state it clearly.
# </think>
#
# The capital of France is **Paris**. It is not only the political and administrative center of the country but also renowned for its cultural landmarks such as the Eiffel Tower, the Louvre Museum, and its historical significance as a hub of art, fashion, and gastronomy.

# %%
model.invoke("What is the capital of France?").content
# Out:
# "<think>\nOkay, so the user is asking for the capital of France. Let me think. I remember that France is a country in Western Europe. The capital... I think it's Paris. Wait, is there any other possibility? Maybe Marseille or Lyon? No, I'm pretty sure Paris is the capital. Let me confirm. Paris is known for the Eiffel Tower and the Louvre, right? And it's a major cultural and historical city. Yeah, I'm pretty confident that Paris is the capital of France. I don't think the capital has changed recently. Let me see if there's any chance I'm mixing it up with another country. For example, Spain's capital is Madrid, Italy's is Rome, so France's should be Paris. Yeah, that's right. So the answer should be Paris.\n</think>\n\nThe capital of France is **Paris**. It is renowned for its cultural landmarks such as the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral, and serves as the political, economic, and cultural center of the country. \n\n**Answer:** Paris."

# %% [markdown]
# pip install --upgrade langchain-google-genai google-generativeai

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
embedding_model=GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %% [markdown]
# import os
# from dotenv import load_dotenv
# load_dotenv(override=True)  # override=True forces it to reload

# %%
doc_vector = embedding_model.embed_query("What is the capital of France?")

# %% [markdown]
# pip install -U langchain-google-genai

# %%
print(doc_vector)

# %% [markdown]
# DATA INGESTION

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
import os
os.getcwd()
# Out:
# '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook'

# %%
file_path=os.path.join(os.getcwd(), "data", "sample.pdf")

# %%
file_path
# Out:
# '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf'

# %%
loader=PyPDFLoader(file_path)

# %%
documents=loader.load()

# %%
len(documents)
# Out:
# 77

# %% [markdown]
# every document here represents a page. Since we have 77 pages, so lenghth is 77. We can do chunking too if we want and its experimental and no definitive size can be there

# %%
text_splitter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=150,
    length_function=len
)

# %%
docs=text_splitter.split_documents(documents)

# %%
len(docs)
# Out:
# 765

# %%
docs[0]
# Out:
# Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 0, 'page_label': '1'}, page_content='Llama 2: Open Foundation and Fine-Tuned Chat Models\nHugo Touvron∗ Louis Martin† Kevin Stone†\nPeter Albert Amjad Almahairi Yasmine Babaei Nikolay Bashlykov Soumya Batra\nPrajjwal Bhargava Shruti Bhosale Dan Bikel Lukas Blecher Cristian Canton Ferrer Moya Chen\nGuillem Cucurull David Esiobu Jude Fernandes Jeremy Fu Wenyin Fu Brian Fuller\nCynthia Gao Vedanuj Goswami Naman Goyal Anthony Hartshorn Saghar Hosseini Rui Hou\nHakan Inan Marcin Kardas Viktor Kerkez Madian Khabsa Isabel Kloumann Artem Korenev')

# %%
docs[0].metadata
# Out:
# {'producer': 'pdfTeX-1.40.25',
#  'creator': 'LaTeX with hyperref',
#  'creationdate': '2023-07-20T00:30:36+00:00',
#  'author': '',
#  'keywords': '',
#  'moddate': '2023-07-20T00:30:36+00:00',
#  'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5',
#  'subject': '',
#  'title': '',
#  'trapped': '/False',
#  'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf',
#  'total_pages': 77,
#  'page': 0,
#  'page_label': '1'}

# %% [markdown]
# 0,1,2,3
# page_lable=4
# actual page is 4
#
# page_index=3
# page_lable=4

# %%
docs[0].page_content
# Out:
# 'Llama 2: Open Foundation and Fine-Tuned Chat Models\nHugo Touvron∗ Louis Martin† Kevin Stone†\nPeter Albert Amjad Almahairi Yasmine Babaei Nikolay Bashlykov Soumya Batra\nPrajjwal Bhargava Shruti Bhosale Dan Bikel Lukas Blecher Cristian Canton Ferrer Moya Chen\nGuillem Cucurull David Esiobu Jude Fernandes Jeremy Fu Wenyin Fu Brian Fuller\nCynthia Gao Vedanuj Goswami Naman Goyal Anthony Hartshorn Saghar Hosseini Rui Hou\nHakan Inan Marcin Kardas Viktor Kerkez Madian Khabsa Isabel Kloumann Artem Korenev'

# %%
#!pip install langchain-huggingface sentence-transformers
#!pip install fastembed

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

doc_vector = embedding_model.embed_query("What is the capital of France?")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 15722.72it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
from langchain_community.embeddings import FastEmbedEmbeddings

embedding_model = FastEmbedEmbeddings(model_name="BAAI/bge-small-en-v1.5")

doc_vector = embedding_model.embed_query("What is the capital of France?")
# Out:
# Fetching 5 files: 100%|██████████| 5/5 [00:02<00:00,  1.82it/s]

# %%
#saving in vector database
from langchain_community.vectorstores import FAISS

# %%
doc_vector=embedding_model.embed_documents(docs[0].page_content)

# %%
len(embedding_model.embed_documents(docs[0].page_content)[0])
# Out:
# 384

# %%
vectorstore=FAISS.from_documents(docs, embedding_model)

# %% [markdown]
# token->words
#
# chunk--> it is collection of words(token)[characters]
#
#
# in memory(faiss is in memory vector store,chroma)
#
# on disk storage(faiss you can persist over the disk,chroma)
# cloud storage(cloud variant of faiss is not available)(pinecone,weaviate,milvus,mongodbvectorsearch,astradb)

# %% [markdown]
# This is a Retrieval proceesss
#
# means from the vectordatabase we are going to fetch or retrive or rank the most appropriate k result

# %%
relevant_doc=vectorstore.similarity_search("llama2 finetuning benchmark experiments.")

# %%
relevant_doc
# Out:
# [Document(id='e13a1977-f5a4-4c43-8699-86fd68772e26', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 48, 'page_label': '49'}, page_content='Llama 2\n7B 77.4 78.8 48.3 77.2 69.2 75.2 45.9 58.6 57.8 45.3\n13B 81.7 80.5 50.3 80.7 72.8 77.3 49.4 57.0 67.3 54.8\n34B 83.7 81.9 50.9 83.3 76.7 79.4 54.5 58.2 74.3 62.6\n70B 85.0 82.8 50.7 85.3 80.2 80.2 57.4 60.2 78.5 68.9\nTable 20: Performance on standard benchmarks.\nHuman-Eval MBPP\npass@1 pass@100 pass@1 pass@80\nMPT 7B 18.3 - 22.6 -\n30B 25.0 - 32.8 -\nFalcon 7B 0.0 - 11.2 -\n40B 0.6 - 29.8 -\nLlama 1\n7B 10.5 36.5 17.7 56.2\n13B 15.8 52.5 22.0 64.0\n33B 21.7 70.7 30.2 73.4\n65B 23.7 79.3 37.7 76.8'),
#  Document(id='16462164-81c4-44fb-8ad9-b0673256b34d', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 2, 'page_label': '3'}, page_content='the community to advance AI alignment research.\nIn this work, we develop and release Llama 2, a family of pretrained and fine-tuned LLMs,Llama 2and\nLlama 2-Chat, at scales up to 70B parameters. On the series of helpfulness and safety benchmarks we tested,\nLlama 2-Chatmodels generally perform better than existing open-source models. They also appear to\nbe on par with some of the closed-source models, at least on the human evaluations we performed (see'),
#  Document(id='eeaf6444-a963-46be-9084-1b8b6fc6ac16', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 2, 'page_label': '3'}, page_content='as ChatGPT, BARD, and Claude. These closed product LLMs are heavily fine-tuned to align with human\npreferences, which greatly enhances their usability and safety. This step can require significant costs in\ncompute and human annotation, and is often not transparent or easily reproducible, limiting progress within\nthe community to advance AI alignment research.\nIn this work, we develop and release Llama 2, a family of pretrained and fine-tuned LLMs,Llama 2and'),
#  Document(id='a7bc0931-0905-4760-a5c8-ac3028a50cf3', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 4, 'page_label': '5'}, page_content='2 Pretraining\nTocreatethenewfamilyof Llama 2models,webeganwiththepretrainingapproachdescribedinTouvronetal.\n(2023), using an optimized auto-regressive transformer, but made several changes to improve performance.\nSpecifically, we performed more robust data cleaning, updated our data mixes, trained on 40% more total\ntokens,doubledthecontextlength,andusedgrouped-queryattention(GQA)toimproveinferencescalability')]

# %%
relevant_doc[0].page_content
# Out:
# 'Llama 2\n7B 77.4 78.8 48.3 77.2 69.2 75.2 45.9 58.6 57.8 45.3\n13B 81.7 80.5 50.3 80.7 72.8 77.3 49.4 57.0 67.3 54.8\n34B 83.7 81.9 50.9 83.3 76.7 79.4 54.5 58.2 74.3 62.6\n70B 85.0 82.8 50.7 85.3 80.2 80.2 57.4 60.2 78.5 68.9\nTable 20: Performance on standard benchmarks.\nHuman-Eval MBPP\npass@1 pass@100 pass@1 pass@80\nMPT 7B 18.3 - 22.6 -\n30B 25.0 - 32.8 -\nFalcon 7B 0.0 - 11.2 -\n40B 0.6 - 29.8 -\nLlama 1\n7B 10.5 36.5 17.7 56.2\n13B 15.8 52.5 22.0 64.0\n33B 21.7 70.7 30.2 73.4\n65B 23.7 79.3 37.7 76.8'

# %%
relevant_doc[2].page_content
# Out:
# 'as ChatGPT, BARD, and Claude. These closed product LLMs are heavily fine-tuned to align with human\npreferences, which greatly enhances their usability and safety. This step can require significant costs in\ncompute and human annotation, and is often not transparent or easily reproducible, limiting progress within\nthe community to advance AI alignment research.\nIn this work, we develop and release Llama 2, a family of pretrained and fine-tuned LLMs,Llama 2and'

# %%
relevant_doc=vectorstore.similarity_search("ReinforcementLearning withHuman Feedback(RLHF).",k=10)

# %%
relevant_doc
# Out:
# [Document(id='6198ae88-dc36-432a-8cf9-e74cb256e4c3', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 8, 'page_label': '9'}, page_content='fine-tune the model for 2 epochs.\n3.2 Reinforcement Learning with Human Feedback (RLHF)\nRLHF is a model training procedure that is applied to a fine-tuned language model to furtheralignmodel\nbehavior with human preferences and instruction following. We collect data that represents empirically\n9'),
#  Document(id='667d8713-a7d2-480d-8c29-31484045f19f', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 1, 'page_label': '2'}, page_content='3 Fine-tuning 8\n3.1 Supervised Fine-Tuning (SFT) . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 9\n3.2 Reinforcement Learning with Human Feedback (RLHF) . . . . . . . . . . . . . . . . . . . . . 9\n3.3 System Message for Multi-Turn Consistency . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 16\n3.4 RLHF Results . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 17\n4 Safety 20'),
#  Document(id='c27a03e2-cd1a-4cee-933f-c26f88867726', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 41, 'page_label': '42'}, page_content='https://doi.org/10.48550/arXiv.2303.08774.\nLong Ouyang, Jeffrey Wu, Xu Jiang, Diogo Almeida, Carroll Wainwright, Pamela Mishkin, Chong Zhang,\nSandhini Agarwal, Katarina Slama, Alex Ray, et al. Training language models to follow instructions with\nhuman feedback.Advances in Neural Information Processing Systems, 35:27730–27744, 2022.\nDavid Patterson, Joseph Gonzalez, Quoc Le, Chen Liang, Lluis-Miquel Munguia, Daniel Rothchild, David'),
#  Document(id='b2ff9164-e91f-4065-8d9b-e8f05a38dd7a', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 35, 'page_label': '36'}, page_content='In this paradigm, models are fine-tuned based on feedback from human users, thus iteratively aligning the\nmodels’ responses more closely with human expectations and preferences.\nOuyang et al. (2022) demonstrates that a combination of instruction fine-tuning and RLHF can help fix\nissues with factuality, toxicity, and helpfulness that cannot be remedied by simply scaling up LLMs. Bai\net al. (2022b) partially automates this fine-tuning-plus-RLHF approach by replacing the human-labeled'),
#  Document(id='e69e49ff-4d90-4557-b4d8-f93872cb2d53', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 4, 'page_label': '5'}, page_content='with Human Feedback(RLHF) methodologies, specifically through rejection sampling and Proximal Policy\nOptimization (PPO). Throughout the RLHF stage, the accumulation ofiterative reward modeling datain\nparallel with model enhancements is crucial to ensure the reward models remain within distribution.\n2 Pretraining\nTocreatethenewfamilyof Llama 2models,webeganwiththepretrainingapproachdescribedinTouvronetal.'),
#  Document(id='75972749-797b-478a-91ea-d56a8303651e', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 10, 'page_label': '11'}, page_content='to form a larger training dataset. Initially, open-source datasets were used to bootstrap our reward models\nwhile we were in the process of collecting preference annotation data. We note that in the context of RLHF in\nthis study, the role of reward signals is to learn human preference forLlama 2-Chatoutputs rather than\nany modeloutputs. However, in our experiments, we do not observe negative transfer from the open-source'),
#  Document(id='1e55337d-5a4d-4828-affc-0db5d23d0d09', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 4, 'page_label': '5'}, page_content='Figure 4: Training ofLlama 2-Chat: This process begins with thepretraining of Llama 2using publicly\navailable online sources. Following this, we create an initial version ofLlama 2-Chatthrough the application\nof supervised fine-tuning. Subsequently, the model is iteratively refined using Reinforcement Learning\nwith Human Feedback(RLHF) methodologies, specifically through rejection sampling and Proximal Policy'),
#  Document(id='3981fdc9-c505-4205-8031-dbea20042b37', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 31, 'page_label': '32'}, page_content='supervised annotation, attracted by its denser signal. Meanwhile reinforcement learning, known for its insta-\nbility, seemed a somewhat shadowy field for those in the NLP research community. However, reinforcement\nlearning proved highly effective, particularly given its cost and time effectiveness. Our findings underscore\nthat the crucial determinant of RLHF’s success lies in the synergy it fosters between humans and LLMs\nthroughout the annotation process.'),
#  Document(id='adf8a630-c679-487d-8e4a-bdc73a2cdcdf', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 8, 'page_label': '9'}, page_content='tions provided by humans with the samples generated by the model through manual scrutiny. Surprisingly,\nwe found that the outputs sampled from the resulting SFT model were often competitive with SFT data\nhandwritten by human annotators, suggesting that we could reprioritize and devote more annotation effort\nto preference-based annotation for RLHF.\nFine-Tuning Details. For supervised fine-tuning, we use a cosine learning rate schedule with an initial'),
#  Document(id='f09adb1c-86ef-47ca-ada2-13ad8a3fcf86', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 12, 'page_label': '13'}, page_content='an improvement forLlama 2-Chat.\n3.2.3 Iterative Fine-Tuning\nAs we received more batches of human preference data annotation, we were able to train better reward\nmodels and collect more prompts. We therefore trained successive versions for RLHF models, referred to\nhere as RLHF-V1, ..., RLHF-V5.\nWe explored RLHF fine-tuning with two main algorithms:\n• Proximal Policy Optimization (PPO)(Schulman et al., 2017), the standard in RLHF literature.')]

# %%
relevant_doc=vectorstore.similarity_search("llama2 finetuning benchmark experiments.",k=1)

# %%
relevant_doc
# Out:
# [Document(id='e13a1977-f5a4-4c43-8699-86fd68772e26', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 48, 'page_label': '49'}, page_content='Llama 2\n7B 77.4 78.8 48.3 77.2 69.2 75.2 45.9 58.6 57.8 45.3\n13B 81.7 80.5 50.3 80.7 72.8 77.3 49.4 57.0 67.3 54.8\n34B 83.7 81.9 50.9 83.3 76.7 79.4 54.5 58.2 74.3 62.6\n70B 85.0 82.8 50.7 85.3 80.2 80.2 57.4 60.2 78.5 68.9\nTable 20: Performance on standard benchmarks.\nHuman-Eval MBPP\npass@1 pass@100 pass@1 pass@80\nMPT 7B 18.3 - 22.6 -\n30B 25.0 - 32.8 -\nFalcon 7B 0.0 - 11.2 -\n40B 0.6 - 29.8 -\nLlama 1\n7B 10.5 36.5 17.7 56.2\n13B 15.8 52.5 22.0 64.0\n33B 21.7 70.7 30.2 73.4\n65B 23.7 79.3 37.7 76.8')]

# %%
# retriever=vectorstore.as_retriever()

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 10})

# %% [markdown]
# you can explore about keyword filtering

# %% [markdown]
# getting same similar documents as above

# %%
retriever.invoke("ReinforcementLearning withHuman Feedback(RLHF).")
# Out:
# [Document(id='6198ae88-dc36-432a-8cf9-e74cb256e4c3', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 8, 'page_label': '9'}, page_content='fine-tune the model for 2 epochs.\n3.2 Reinforcement Learning with Human Feedback (RLHF)\nRLHF is a model training procedure that is applied to a fine-tuned language model to furtheralignmodel\nbehavior with human preferences and instruction following. We collect data that represents empirically\n9'),
#  Document(id='667d8713-a7d2-480d-8c29-31484045f19f', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 1, 'page_label': '2'}, page_content='3 Fine-tuning 8\n3.1 Supervised Fine-Tuning (SFT) . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 9\n3.2 Reinforcement Learning with Human Feedback (RLHF) . . . . . . . . . . . . . . . . . . . . . 9\n3.3 System Message for Multi-Turn Consistency . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 16\n3.4 RLHF Results . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 17\n4 Safety 20'),
#  Document(id='c27a03e2-cd1a-4cee-933f-c26f88867726', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 41, 'page_label': '42'}, page_content='https://doi.org/10.48550/arXiv.2303.08774.\nLong Ouyang, Jeffrey Wu, Xu Jiang, Diogo Almeida, Carroll Wainwright, Pamela Mishkin, Chong Zhang,\nSandhini Agarwal, Katarina Slama, Alex Ray, et al. Training language models to follow instructions with\nhuman feedback.Advances in Neural Information Processing Systems, 35:27730–27744, 2022.\nDavid Patterson, Joseph Gonzalez, Quoc Le, Chen Liang, Lluis-Miquel Munguia, Daniel Rothchild, David'),
#  Document(id='b2ff9164-e91f-4065-8d9b-e8f05a38dd7a', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 35, 'page_label': '36'}, page_content='In this paradigm, models are fine-tuned based on feedback from human users, thus iteratively aligning the\nmodels’ responses more closely with human expectations and preferences.\nOuyang et al. (2022) demonstrates that a combination of instruction fine-tuning and RLHF can help fix\nissues with factuality, toxicity, and helpfulness that cannot be remedied by simply scaling up LLMs. Bai\net al. (2022b) partially automates this fine-tuning-plus-RLHF approach by replacing the human-labeled'),
#  Document(id='e69e49ff-4d90-4557-b4d8-f93872cb2d53', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 4, 'page_label': '5'}, page_content='with Human Feedback(RLHF) methodologies, specifically through rejection sampling and Proximal Policy\nOptimization (PPO). Throughout the RLHF stage, the accumulation ofiterative reward modeling datain\nparallel with model enhancements is crucial to ensure the reward models remain within distribution.\n2 Pretraining\nTocreatethenewfamilyof Llama 2models,webeganwiththepretrainingapproachdescribedinTouvronetal.'),
#  Document(id='75972749-797b-478a-91ea-d56a8303651e', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 10, 'page_label': '11'}, page_content='to form a larger training dataset. Initially, open-source datasets were used to bootstrap our reward models\nwhile we were in the process of collecting preference annotation data. We note that in the context of RLHF in\nthis study, the role of reward signals is to learn human preference forLlama 2-Chatoutputs rather than\nany modeloutputs. However, in our experiments, we do not observe negative transfer from the open-source'),
#  Document(id='1e55337d-5a4d-4828-affc-0db5d23d0d09', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 4, 'page_label': '5'}, page_content='Figure 4: Training ofLlama 2-Chat: This process begins with thepretraining of Llama 2using publicly\navailable online sources. Following this, we create an initial version ofLlama 2-Chatthrough the application\nof supervised fine-tuning. Subsequently, the model is iteratively refined using Reinforcement Learning\nwith Human Feedback(RLHF) methodologies, specifically through rejection sampling and Proximal Policy'),
#  Document(id='3981fdc9-c505-4205-8031-dbea20042b37', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 31, 'page_label': '32'}, page_content='supervised annotation, attracted by its denser signal. Meanwhile reinforcement learning, known for its insta-\nbility, seemed a somewhat shadowy field for those in the NLP research community. However, reinforcement\nlearning proved highly effective, particularly given its cost and time effectiveness. Our findings underscore\nthat the crucial determinant of RLHF’s success lies in the synergy it fosters between humans and LLMs\nthroughout the annotation process.'),
#  Document(id='adf8a630-c679-487d-8e4a-bdc73a2cdcdf', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 8, 'page_label': '9'}, page_content='tions provided by humans with the samples generated by the model through manual scrutiny. Surprisingly,\nwe found that the outputs sampled from the resulting SFT model were often competitive with SFT data\nhandwritten by human annotators, suggesting that we could reprioritize and devote more annotation effort\nto preference-based annotation for RLHF.\nFine-Tuning Details. For supervised fine-tuning, we use a cosine learning rate schedule with an initial'),
#  Document(id='f09adb1c-86ef-47ca-ada2-13ad8a3fcf86', metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2023-07-20T00:30:36+00:00', 'author': '', 'keywords': '', 'moddate': '2023-07-20T00:30:36+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) kpathsea version 6.3.5', 'subject': '', 'title': '', 'trapped': '/False', 'source': '/Users/ruchisehgal/Documents/Study Material/Industry Ready projects-LLMOPS/document_portal/notebook/data/sample.pdf', 'total_pages': 77, 'page': 12, 'page_label': '13'}, page_content='an improvement forLlama 2-Chat.\n3.2.3 Iterative Fine-Tuning\nAs we received more batches of human preference data annotation, we were able to train better reward\nmodels and collect more prompts. We therefore trained successive versions for RLHF models, referred to\nhere as RLHF-V1, ..., RLHF-V5.\nWe explored RLHF fine-tuning with two main algorithms:\n• Proximal Policy Optimization (PPO)(Schulman et al., 2017), the standard in RLHF literature.')]

# %% [markdown]
# Question: user question
#
# Context: based on the question retrieving the info from the vector database

# %%
prompt_template = """
        Answer the question based on the context provided below. 
        If the context does not contain sufficient information, respond with: 
        "I do not have enough information about this."

        Context: {context}

        Question: {question}

        Answer:"""

# %%
from langchain_core.prompts import PromptTemplate

# %%
#pip install -U langchain langchain-core langchain-community
# #pip install -U "langchain~=0.2.10" "langchain-core~=0.2.10"
prompt= PromptTemplate(
    template=prompt_template,
    input_variables=['context','question']
)
prompt
# Out:
# PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='\n        Answer the question based on the context provided below. \n        If the context does not contain sufficient information, respond with: \n        "I do not have enough information about this."\n\n        Context: {context}\n\n        Question: {question}\n\n        Answer:')

# %%
#Now we have to create the RAG chain WITH Chaining concept
#StrOutputParser convert the output into string
from langchain_core.output_parsers import StrOutputParser
parser=StrOutputParser()
rag_chain= prompt|llm|parser

# %%
#Inside the chain, we want context from receiver and user question 
#and format_docs will provide the PAGE CONTENT only and RunnablePassthrough() is used to get the question on run time.
#format_docs --METHOD NAME IS GETTING CREATED
from langchain_core.runnables import RunnablePassthrough
def format_docs(docs):
    return "\n\n".join([doc.page_content for doc in docs])

rag_chain=(

    {"context":retriever | format_docs, "question": RunnablePassthrough()}

    | prompt | model | StrOutputParser()
)
